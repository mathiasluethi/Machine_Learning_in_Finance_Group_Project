# %% [markdown]
# # ML in Finance Group Project
# ## Group 2: Barbara Capl, Mathias Lüthi, Pamela Matias, Stefanie Rentsch
# ### 1. Preparing the data
# In this part of the code the data is imported from the Wharton data source. It's than cleaned up and put into usable attribute matrices for further feature selection.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# %% [markdown]
# The financial data from the Wharton Database is loaded in. The redundant identification columns and columns which are more than 2/3 empty values are droped.
# The financial ratios from the Wharton Database are loaded in. The adate and qdate are dropped because they are not relevant.

# %%
# Load in data from the Wharton Database
df = pd.read_csv('Data/WhartonData.csv', sep=',', header=0)

df = df.drop(['NAMEENDT','SHRCD','EXCHCD','SICCD','TICKER','COMNAM', 'NCUSIP', 'TSYMBOL',
              'PERMCO', 'ISSUNO', 'HSICCD'], 1)
df = df.drop(['DLAMT', 'DLPDT', 'SPREAD', 'DLSTCD', 'NEXTDT', 'HSICMG', 'HSICIG', 'DIVAMT',
              'SHRCLS', 'ACPERM', 'ACCOMP', 'NWPERM', 'DLRETX', 'DLPRC', 'DLRET', 'NMSIND',
              'MMCNT', 'NSDINX', 'DCLRDT', 'PAYDT', 'RCRDDT', 'DISTCD', 'FACPR', 'FACSHR',
              'TRTSCD', ], 1)

df.columns.values[0] = 'permno'

df['date'] = df.date.astype(str).str[:4] + '-' + df.date.astype(str).str[4:6]

# print(df.isnull().sum())
# display(df.head())

# %%
# Load in the Ratios
ratios = pd.read_csv('Data/Ratios.csv', sep=',', header=0)

ratios = ratios.drop(['adate', 'qdate'], 1)

ratios.columns.values[1] = 'date'
ratios['date'] = ratios.date.str[6:] + '-' + ratios.date.str[3:5]

# print(ratios.isnull().sum())
# display(ratios.head())

# %%
# Merging the two dataframes
data = pd.merge(df, ratios, left_on=['date', 'permno'], right_on=['date', 'permno'])
display(data.head())
# Out:
#    permno     date     NAICS PRIMEXCH TRDSTAT SECSTAT  HEXCD     CUSIP  \
# 0   10107  2006-01  511210.0        Q       A       R      3  59491810
# 1   10107  2006-02  511210.0        Q       A       R      3  59491810
# 2   10107  2006-03  511210.0        Q       A       R      3  59491810
# 3   10107  2006-04  511210.0        Q       A       R      3  59491810
# 4   10107  2006-05  511210.0        Q       A       R      3  59491810
#
#    SHRFLG    SHRENDDT       ...        sale_nwc  rd_sale  adv_sale  \
# 0     0.0  20060330.0       ...           1.296    0.151     0.025
# 1     0.0         NaN       ...           1.323    0.151     0.025
# 2     0.0  20060423.0       ...           1.323    0.151     0.025
# 3     0.0  20060629.0       ...           1.323    0.151     0.025
# 4     0.0         NaN       ...           1.388    0.150     0.025
#
#    staff_sale accrual    ptb  PEG_trailing  divyield  PEG_1yrforward  \
# 0         0.0   0.055  6.019        11.538     1.14%          15.506
# 1         0.0   0.036  6.281        10.280     1.34%          14.555
# 2         0.0   0.036  6.293        10.410     1.32%          14.739
# 3         0.0   0.036  5.573         9.239     1.49%          13.081
# 4         0.0   0.024  5.496         0.709     1.59%          -5.842
#
#    PEG_ltgforward
# 0           2.109
# 1           1.838
# 2           1.842
# 3           1.666
# 4           1.480
#
# [5 rows x 99 columns]

# %%
# Creating a responce vector and an attribute matrix
forcast_periods = [1, 3, 6, 12]
for i in forcast_periods:
    data['return_' + str(i)] = np.where((data['permno'] == data['permno'].shift(i)), data['PRC'] / data['PRC'].shift(i), None)

# data_1 = data[data['return_1'] is None]
#response_1 = np.where(data[return_1] >= 1, 1, 0) 
#attributes = data.iloc[:, 2:-4]

#display(response.head())
#display(attributes.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-82695edf60b5> in <module>()
#       4     data['return_' + str(i)] = np.where((data['permno'] == data['permno'].shift(i)), data['PRC'] / data['PRC'].shift(i), None)
#       5
# ----> 6 data_1 = data[data['return_1'] is None]
#       7 #response_1 = np.where(data[return_1] >= 1, 1, 0)
#       8 #attributes = data.iloc[:, 2:-4]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
